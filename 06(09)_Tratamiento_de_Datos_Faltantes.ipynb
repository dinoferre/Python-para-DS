# %% [markdown]
# <a href="https://colab.research.google.com/github/dinoferre/Python-para-DS/blob/main/06(09)_Tratamiento_de_Datos_Faltantes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Reporte de Análisis V

# %% [markdown]
# ## Tratamiento de Datos Faltantes

# %%
import pandas as pd

# %%
datos = pd.read_csv('alquiler_residencial.csv', sep = ';')

# %%
datos.head(10)
# Out:
#                  Tipo     Distrito  Cuartos  Vacantes  Suites  Area    Valor  \
# 0          Habitación    San Borja        1         0       0    40   1700.0
# 1                Casa   Lurigancho        2         0       1   100   7000.0
# 2        Departamento   Pachacámac        1         0       0    15    800.0
# 3        Departamento          Ate        1         0       0    48    800.0
# 4        Departamento        Comas        2         0       0    50   1300.0
# 5  Casa en condominio          Ate        5         4       5   750  22000.0
# 6  Casa en condominio  El Agustino        2         2       0    65   1000.0
# 7        Departamento      Mi Perú        2         1       0    70   1500.0
# 8        Departamento    San Borja        3         1       1    90   1500.0
# 9        Departamento    San Borja        1         0       1    40   2000.0
#
#    Mantenimiento  Impuesto  Valor m2 Tipo Agrupado
# 0          500.0      60.0     42.50  Departamento
# ...

# %%
datos.isnull()
# Out:
#         Tipo  Distrito  Cuartos  Vacantes  Suites   Area  Valor  \
# 0      False     False    False     False   False  False  False
# 1      False     False    False     False   False  False  False
# 2      False     False    False     False   False  False  False
# 3      False     False    False     False   False  False  False
# 4      False     False    False     False   False  False  False
# ...      ...       ...      ...       ...     ...    ...    ...
# 15320  False     False    False     False   False  False  False
# 15321  False     False    False     False   False  False  False
# 15322  False     False    False     False   False  False  False
# 15323  False     False    False     False   False  False  False
# 15324  False     False    False     False   False  False  False
#
#        Mantenimiento  Impuesto  Valor m2  Tipo Agrupado
# 0              False     False     False          False
# 1              False     False     False          False
# ...

# %%
datos.notnull()
# Out:
#        Tipo  Distrito  Cuartos  Vacantes  Suites  Area  Valor  Mantenimiento  \
# 0      True      True     True      True    True  True   True           True
# 1      True      True     True      True    True  True   True           True
# 2      True      True     True      True    True  True   True           True
# 3      True      True     True      True    True  True   True           True
# 4      True      True     True      True    True  True   True           True
# ...     ...       ...      ...       ...     ...   ...    ...            ...
# 15320  True      True     True      True    True  True   True           True
# 15321  True      True     True      True    True  True   True           True
# 15322  True      True     True      True    True  True   True           True
# 15323  True      True     True      True    True  True   True           True
# 15324  True      True     True      True    True  True   True           True
#
#        Impuesto  Valor m2  Tipo Agrupado
# ...

# %%
datos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15325 entries, 0 to 15324
# Data columns (total 11 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Tipo           15325 non-null  object
#  1   Distrito       15325 non-null  object
#  2   Cuartos        15325 non-null  int64
#  3   Vacantes       15325 non-null  int64
#  4   Suites         15325 non-null  int64
#  5   Area           15325 non-null  int64
#  6   Valor          15325 non-null  float64
#  7   Mantenimiento  15325 non-null  float64
#  8   Impuesto       15324 non-null  float64
#  9   Valor m2       15324 non-null  float64
#  10  Tipo Agrupado  15324 non-null  object
# dtypes: float64(4), int64(4), object(3)
# memory usage: 1.3+ MB

# %%
datos[datos['Valor'].isnull()]
# Out:
# Empty DataFrame
# Columns: [Tipo, Distrito, Cuartos, Vacantes, Suites, Area, Valor, Mantenimiento, Impuesto, Valor m2, Tipo Agrupado]
# Index: []

# %%
A = datos.shape[0]
datos.dropna(subset = ['Valor'], inplace = True)
B = datos.shape[0]
A - B
# Out:
# 0

# %%
datos[datos['Valor'].isnull()]
# Out:
# Empty DataFrame
# Columns: [Tipo, Distrito, Cuartos, Vacantes, Suites, Area, Valor, Mantenimiento, Impuesto, Valor m2, Tipo Agrupado]
# Index: []

# %% [markdown]
# ## Tratamiento de Datos Faltantes (continuación)

# %%
datos[datos['Mantenimiento'].isnull()].shape[0]
# Out:
# 0

# %%
seleccion = (datos['Tipo'] == 'Departamento') & (datos['Mantenimiento'].isnull())

# %%
A = datos.shape[0]
datos = datos[~seleccion]
B = datos.shape[0]
A - B
# Out:
# 0

# %%
datos[datos['Mantenimiento'].isnull()].shape[0]
# Out:
# 0

# %%
datos = datos.fillna({'Mantenimiento': 0, 'Impuesto': 0})

# %%
datos[datos['Mantenimiento'].isnull()].shape[0]
# Out:
# 0

# %%
datos[datos['Impuesto'].isnull()].shape[0]
# Out:
# 0

# %%
datos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 15325 entries, 0 to 15324
# Data columns (total 11 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Tipo           15325 non-null  object
#  1   Distrito       15325 non-null  object
#  2   Cuartos        15325 non-null  int64
#  3   Vacantes       15325 non-null  int64
#  4   Suites         15325 non-null  int64
#  5   Area           15325 non-null  int64
#  6   Valor          15325 non-null  float64
#  7   Mantenimiento  15325 non-null  float64
#  8   Impuesto       15325 non-null  float64
#  9   Valor m2       15324 non-null  float64
#  10  Tipo Agrupado  15324 non-null  object
# dtypes: float64(4), int64(4), object(3)
# memory usage: 1.4+ MB

# %%
datos.to_csv('alquiler_residencial.csv', sep = ';', index = False)
